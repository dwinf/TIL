# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
table_def = pd.read_csv('./data/01-1_정형데이터_테이블정의서_상권집계.csv', encoding='cp949')
data2 = pd.read_csv('./data/01-2_정형데이터_서비스업종소분류_업종테이블.csv', encoding='cp949')
data3 = pd.read_csv('./data/01-3_정형데이터_2021.02_상권집계_서울.csv', encoding='cp949')
data4 = pd.read_csv('./data/02-1_비정형데이터_블로그_맛집.csv')

# %%
data2 = pd.read_csv('./data/01-2_정형데이터_서비스업종소분류_업종테이블.csv', encoding='cp949')
data2
# Out:
#     svc_dv_cd svc_tpbuz_scls_cd svc_tpbuz_scls_nm svc_tpbuz_mcls_cd
# 0        SD02            MD0001             내과/외과              MD00
# 1        SD02            MD0002                치과              MD00
# 2        SD02            MD0003           정형/성형외과              MD00
# 3        SD02            MD0004             이비인후과              MD00
# 4        SD02            MD0005                안과              MD00
# ..        ...               ...               ...               ...
# 159      SD01            RS0302             캠핑/펜션              RS03
# 160      SD01            RS0401            휘트니스센터              RS04
# 161      SD01            RS0402                골프              RS04
# 162      SD01            LS0104            안마/마사지              LS01
# 163      SD01            RS0104              기타오락              RS01
#
# [164 rows x 4 columns]

# %%
data3 = pd.read_csv('./data/01-3_정형데이터_2021.02_상권집계_서울.csv', encoding='cp949')
data3
# Out:
#         strd_yymm nw_mail_no svc_tpbuz_scls_cd   sale_amt  sale_cnt  mer_num  \
# 0          202102      0553*            FD0602  1000700.0     155.0        1
# 1          202102      0665*            FD0302  9466500.0     396.0        1
# 2          202102      0795*            SL0201  2817100.0      42.0        2
# 3          202102      0432*            FD0201  8701000.0     441.0        1
# 4          202102      0874*            FD0602  6677390.0     643.0        1
# ...           ...        ...               ...        ...       ...      ...
# 188624     202102      0280*            FD0201  3808000.0     152.0        2
# 188625     202102      0617*            LS0601   456500.0       2.0        1
# 188626     202102      0575*            ED0101   456000.0       1.0        1
# 188627     202102      0585*            FD0903  9712500.0     938.0        3
# 188628     202102      0147*            FD1202   170000.0       3.0        2
#
# ...
