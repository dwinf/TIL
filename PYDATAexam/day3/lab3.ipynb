# %%
import requests
from bs4 import BeautifulSoup
import re

req = requests.get('https://news.daum.net/ranking/popular') # 파이썬은 문자열 결합시 타입이 동일해야 함
#req.encoding = 'utf-8'
html = req.text
soup = BeautifulSoup(html, 'html.parser')

title = soup.select('#mArticle > div.rank_news li strong > a')
comname = soup.select('#mArticle > div.rank_news li strong > span')
newstitle = []
newscomname = []
for dom in title:
    dom=re.sub(",", '', dom.text)
    newstitle.append(dom)
    print(dom)
for dom in comname:
    newscomname.append(dom.string)
    print(dom.string)

with open('output/news.csv', "wt", encoding="utf-8") as f:
    f.write('newstitle,newscomname\n')  
    for i in range(len(newstitle)):
        f.write(newstitle[i]+","+newscomname[i]+'\n')
# Out:
# 시장에서 산 고둥서 나온 돌 알고보니 수천만원 '희귀 진주'
# 노원구 아파트서 세 모녀 숨진채 발견..용의자는 자해
# "'구미 3세 사망 여아' 나올 수 없는 혈액형 둘 다 외도?" [황출새]
# [제보는Y] "살려달라" 비명에 신고한 배송기사..피 흘리던 종업원 구해
# '건강 이상설' 돈 79세 바이든..기자회견 중 "어디까지 말했나"
# 베이비박스에 아이 넣고 돌아서는 순간 일어나는 일
# 월 15만원에 깨끗한 집 빌려주자 동네 소원이 이뤄졌다 [월간 옥이네]
# "혹시 당근이세요?"..'만남의 광장'으로  변신한 중고거래앱
# '구미 3세 여아' 친모·큰딸 모두 외도?.."나올 수 없는 혈액형"
# '혈액형에서 단서 찾았다'..구미 여아 사건 실마리 풀리나
# 오세훈 "중증치매 환자..대통령에게 그 정도 말도 못하나"
# [사건의 재구성]"미안 형편 어려워.." 혼수상태 아내 호흡기 뗀 남편
# "전생에 우린 연인 관계였다"..친딸 성폭행한 아빠 '징역 13년'
# "美인도·태평양사령부 日요구에 '동해' 표기 정정"<교도>
# [시선집중] 이상돈 "안철수 도움보다 피곤하게 할 거라는 걸 김종인도 아는 것"
# 석달 밀린 월급 달랬더니 기름 뿌린 9만 1500개의 동전 집 앞에
# [특파원 시선] 1988년 서울올림픽 엠블럼이 이탈리아 주유소에?
# [단독] 박형준 정무수석 시절 국정원 '사찰 문건' 원문 공개 ②
# 입원중인 이재용 부회장 1인실서 4명의 순환감시..국가가 부담하나
# "순두부찌개 맛없어 밥값 못준다" 난동..벌금 800만원
# 부산어시장에 등장한 '바다의 로또' 참다랑어 2천마리
# 바이든 中에 재차 경고.."내 눈앞에서 세계 최강국 되는 일 없을 것"
# "서당 보낸 딸 악마보다 더한 폭행·성적 고문에 엉망됐다..제발"
# 대통령 백신 바꿔치기 의혹 "청맹과니나 하는 짓"
# "백반 한 끼 1000원 식당주인..지갑은 적자 마음은 부자"
# '바닥 민심'에 안 꽂히는 오세훈 내곡동 총공세 왜?
# 호주 대중국 건초 수출 제동..부메랑 맞은 중국
# 삼성중 컨선 20척 2조8천억원에 수주..단일계약으론 세계 최대
# 정 총리 "현행 거리두기 2주 연장..5인 모임 금지도 유지"
# 미인대회 출전 미스 미얀마 국제사회에 "우리 국민 도와주세요"
# [술 취한 의사들 ①] "점심에 소주 반 병 응급실서 와인 진료"..병원 특유의 폐쇄성으로 그저 '쉬쉬'
# "DNA 나왔으면 할 수 없네요" 이춘재도 DNA로 잡았다
# 김종인 "윤석열 별의순간 포착..잘 준비하면 진짜 별 딴다"
# "합석 거부하자 음식 기다리던 중 쫓겨났습니다" [지금e슈]
# 평균 연봉 1억원 시대?..웃지못하는 은행권
# '생파 5번' 남양주시장에.."월급이 부끄럽다" 대신 사과한 공무원
# 구미 친모와 큰딸 '바꿔치기' 공모했나..또 반전
# 오세훈이 박영선 앞서자 親文 "요즘 20대는 철이 없어서.."
# "미혼동료가 유부남과 호텔 들어가더라"..허위사실 40대 남성 집유
# 국민의힘 "안철수 개별입당" vs 국민의당 "합당"..물밑 '기싸움'
# 아시나요? 동백꽃은 세 번 핍니다
# 文 34% 최저치 경신 40대도 흔들..민주당 32% 동반 최저(종합)
# 노원구 아파트서 세 모녀 피살.. 20대 피의자 현장서 자해
# [영상] '여기 도와주세요!' 트럭 세워 주인 살린 반려견
# 군에 끌려간 12만명이 굶어죽고 얼어죽었다
# 식약처 수입 프로바이오틱스 제품 4건 '부적합'..회수 조치
# '생후 20일 아기를 거꾸로'.. 산후도우미 학대 폭로글 등장
# 유령도시로 변한 산티아고..칠레 초강력 코로나 봉쇄령 발동
# "기부받은 10억 다시 기부"..美 증오범죄 피해 할머니의 결심
# [현장영상] "2주간 현행 거리두기 단계·5인 이상 모임 금지 유지"
# 서울신문
# 뉴시스
# YTN
# YTN
# 머니투데이
# 오마이뉴스
# 오마이뉴스
# 뉴스1
# 머니투데이
# KBS
# 연합뉴스
# 뉴스1
# 이데일리
# 연합뉴스
# MBC
# 서울신문
# 연합뉴스
# MBC
# 이데일리
# 뉴시스
# 연합뉴스
# 뉴스1
# 머니투데이
# 미디어오늘
# 노컷뉴스
# 한국일보
# 아시아경제
# 연합뉴스
# 뉴시스
# 연합뉴스
# 데일리안
# 머니투데이
# 연합뉴스
# 데일리안
# 디지털타임스
# 머니투데이
# 노컷뉴스
# 조선일보
# 뉴스1
# 헤럴드경제
# 오마이뉴스
# 뉴스1
# 조선일보
# SBS
# 프레시안
# 연합뉴스
# 파이낸셜뉴스
# 서울신문
# 서울신문
# YTN
